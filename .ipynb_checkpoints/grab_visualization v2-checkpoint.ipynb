# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
import numpy as np
# %matplotlib inline

# %%
#import the data
df = pd.read_csv('grab.csv', parse_dates=True)

# %% [markdown]
# ## Filter data for anomalies/outliers

# %%
#ignore data with pick-up or drop-off locations outside the philippines
df = df[(df['pick_up_latitude'] <20) & (df['pick_up_latitude'] >5)]
df = df[(df['pick_up_longitude'] <127) & (df['pick_up_longitude'] >117)]
df = df[(df['drop_off_latitude'] <20) & (df['drop_off_latitude'] >5)]
df = df[(df['drop_off_longitude'] <127) & (df['drop_off_longitude'] >117)]
df.shape
# Out:
# (265052, 10)

# %% [markdown]
# # iPhone and Android are the major channels used for booking

# %%
print(df.source.value_counts())
df.source.value_counts().plot(kind='bar', figsize=(10,8))
plt.grid(True, alpha=0.2)
plt.title('Grab Booking Source', fontsize=18)
plt.ylabel('Count (Booking Source)', fontsize=14);
# Out:
# IOS    153391
# ADR     98671
# T47      6365
# VNU      6131
# WIN       479
# BBA        15
# Name: source, dtype: int64

# %% [markdown]
# # Most bookings were done in Metro Manila

# %%
print(df.city.value_counts())
df.city.value_counts().plot(kind='bar', figsize=(6,6))
plt.grid(True, alpha=0.2)
plt.title('Cities', fontsize=18)
plt.ylabel('Count (City)', fontsize=14);
# Out:
# Metro Manila    264361
# Cebu               580
# Davao              111
# Name: city, dtype: int64

# %% [markdown]
# # Pick-up and Drop-off Locations

# %%
plt.figure(figsize=(16,12))
plt.subplot(121)
my_map = Basemap(projection='merc', lat_0=57, lon_0=-135,
    resolution = 'l', area_thresh = 1000.0,
    llcrnrlon=115, llcrnrlat=4,
    urcrnrlon=130, urcrnrlat=21)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='cyan', alpha=0.11)
my_map.drawmapboundary() 
my_map.drawmeridians(np.arange(0, 360, 5), labels=[1,0,0,1])
my_map.drawparallels(np.arange(-90, 90, 5),labels=[1,0,0,1])

lons = list(df.pick_up_longitude)
lats = list(df.pick_up_latitude)
x,y = my_map(lons, lats)
my_map.plot(x, y, 'bo', markersize=5, alpha=0.3)
plt.title('Pick-up Locations', fontsize=22)

#drop_off
plt.subplot(122)
my_map = Basemap(projection='merc', lat_0=57, lon_0=-135,
    resolution = 'l', area_thresh = 1000.0,
    llcrnrlon=115, llcrnrlat=4,
    urcrnrlon=130, urcrnrlat=21)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='cyan', alpha=0.11)
my_map.drawmapboundary() 
my_map.drawmeridians(np.arange(0, 360, 5), labels=[1,0,0,1])
my_map.drawparallels(np.arange(-90, 90, 5),labels=[1,0,0,1])
lons = list(df.drop_off_longitude)
lats = list(df.drop_off_latitude)
x,y = my_map(lons, lats)
my_map.plot(x, y, 'ro', markersize=5, alpha=0.3)
plt.title('Drop-off Locations', fontsize=22);

# %% [markdown]
# # Booking Allocation

# %%
print(df.state.value_counts())
mpl.rcParams['font.size'] = 16
plt.figure(figsize=(10,8))
val = list(df.state.value_counts())
label = list(df.state.value_counts().index)
explode=(0.0, 0.05, 0.0)
plt.pie(val, labels=label, autopct='%1.1f%%', explode=explode, shadow=True, startangle=287)
plt.title('Booking State Distribution', fontsize=22);
# Out:
# UNALLOCATED    120515
# COMPLETED      114583
# CANCELLED       29954
# Name: state, dtype: int64

# %% [markdown]
# # Booking Time and Date

# %%
#Create new Columns for hour and weekday
df['created_at_local'] = pd.to_datetime(df['created_at_local'])
df['day_of_week_num'] = df['created_at_local'].dt.dayofweek
days = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
df['day_of_week'] = df['day_of_week_num'].apply(lambda x:days[x])
df['hour_of_day'] = df['created_at_local'].dt.hour

# %%
comp = df.pivot_table(index=['hour_of_day', 'state'], values='city', aggfunc='count')
df_hour = comp.to_frame()
df_hour = df_hour.unstack(level='state')
df_hour['AAR'] = 100*df_hour['city', 'COMPLETED']/(df_hour['city', 'CANCELLED'] + df_hour['city', 'COMPLETED'] + 
                                               df_hour['city', 'UNALLOCATED'])
df_hour['AR'] = 100*(df_hour['city', 'COMPLETED'] + df_hour['city', 'CANCELLED']) /(df_hour['city', 'CANCELLED'] + 
                                                df_hour['city', 'COMPLETED'] + df_hour['city', 'UNALLOCATED'])

df_hour.iloc[:,0:3].plot(kind='bar', stacked=True, figsize=(12,7))
L=plt.legend()
L.get_texts()[0].set_text('CANCELLED')
L.get_texts()[1].set_text('COMPLETED')
L.get_texts()[2].set_text('UNALLOCATED')
plt.ylabel('Total Bookings', fontsize=18)
plt.xlabel('Hour of Day', fontsize=18)
plt.title('Bookings by Hour of Day', fontsize=22)
plt.grid(True, alpha=0.3)

# %%
df_hour.iloc[:,3:5].plot(kind='bar', stacked=False, figsize=(12,7))
L=plt.legend()
L.get_texts()[0].set_text('Actual Allocation Rate')
L.get_texts()[1].set_text('Allocation Rate')
plt.xlabel('Hour of Day', fontsize=18)
plt.title('Allocation Rate by Hour of Day', fontsize=22)
plt.grid(True, alpha=0.3)

# %%
plt.figure(figsize=(12,12))
plt.subplot(211)
df_hour.iloc[:,0:3].plot(kind='bar', stacked=True, ax=plt.gca());
L=plt.legend()
L.get_texts()[0].set_text('CANCELLED')
L.get_texts()[1].set_text('COMPLETED')
L.get_texts()[2].set_text('UNALLOCATED')
plt.ylabel('Total Bookings', fontsize=18)
plt.xlabel('Hour of Day', fontsize=18)
plt.title('Bookings by Hour of Day', fontsize=22)
plt.grid(True, alpha=0.3)

plt.subplot(212)
df_hour.iloc[:,3:5].plot(kind='bar', stacked=False, ax=plt.gca());
M=plt.legend()
M.get_texts()[0].set_text('Actual Allocation Rate')
M.get_texts()[1].set_text('Allocation Rate')
plt.ylabel('Percent Allocation Rate', fontsize=18)
plt.xlabel('Hour of Day', fontsize=18)
plt.title('Bookings by Hour of Day', fontsize=22)
plt.grid(True, alpha=0.3)
plt.tight_layout()

# %%
days = df.pivot_table(index=['day_of_week_num', 'state'], values='city', aggfunc='count')
df_days = days.to_frame()
df_days = df_days.unstack(level='state')
lbl = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
ax = df_days.plot(kind='bar', stacked=True, figsize=(10,8))
L=plt.legend()
L.get_texts()[0].set_text('CANCELLED')
L.get_texts()[1].set_text('COMPLETED')
L.get_texts()[2].set_text('UNALLOCATED')
ax.set_xticklabels(lbl, rotation=90)
plt.ylabel('Total Bookings', fontsize=18)
plt.xlabel('Day of Week', fontsize=18)
plt.title('Bookings by Day of Week', fontsize=22)
plt.grid(True, alpha=0.3)

# %%
#uber_data['MonthDayNum'] = uber_data['Date/Time'].dt.day
df['month_day_num'] = df['created_at_local'].dt.day

plt.figure(figsize=(16,12))
plt.subplot(2,2,1)
df_sept = df[(df['created_at_local']>='2013-09-01') & (df['created_at_local']<='2013-09-30 23:59:59')]
grab_monthdays = df_sept.pivot_table(index=['month_day_num'],
                                  values='city',
                                  aggfunc='count')
grab_monthdays.plot(kind='bar')
plt.ylabel('Count (Bookings)', fontsize=14)
plt.title('Bookings by Month Day (September 2013)', fontsize=18)
plt.grid(True, alpha=0.2)
plt.ylim((0, 15000))

plt.subplot(2,2,2)
df_oct = df[(df['created_at_local']>='2013-10-01') & (df['created_at_local']<='2013-10-31 23:59:59')]
grab_monthdays = df_oct.pivot_table(index=['month_day_num'],
                                  values='city',
                                  aggfunc='count')
grab_monthdays.plot(kind='bar')
plt.title('Bookings by Month Day (October 2013)', fontsize=18)
plt.grid(True, alpha=0.2)
plt.ylim((0, 15000))

plt.subplot(2,2,3)
df_nov = df[(df['created_at_local']>='2013-11-01') & (df['created_at_local']<='2013-11-30 23:59:59')]
grab_monthdays = df_nov.pivot_table(index=['month_day_num'],
                                  values='city',
                                  aggfunc='count')
grab_monthdays.plot(kind='bar')
plt.ylabel('Count (Bookings)', fontsize=14)
plt.title('Bookings by Month Day (November 2013)', fontsize=18)
plt.grid(True, alpha=0.2)
plt.ylim((0, 15000))

plt.subplot(2,2,4)
df_dec = df[(df['created_at_local']>='2013-12-01') & (df['created_at_local']<='2013-12-31 23:59:59')]
grab_monthdays = df_dec.pivot_table(index=['month_day_num'],
                                  values='city',
                                  aggfunc='count')
grab_monthdays.plot(kind='bar')
plt.title('Bookings by Month Day (December 2013)', fontsize=18)
plt.grid(True, alpha=0.2)
plt.ylim((0, 15000))

plt.tight_layout()

# %%
df.describe()
# Out:
#        pick_up_latitude  pick_up_longitude  drop_off_latitude  \
# count     265052.000000      265052.000000      265052.000000
# mean          14.561798         121.046547          14.559122
# std            0.291450           0.182863           0.297272
# min            6.287170         118.482055           6.116870
# 25%           14.552890         121.018340          14.550930
# 50%           14.571390         121.034437          14.566120
# 75%           14.600570         121.057020          14.604960
# max           18.631310         125.828910          18.256870
#
#        drop_off_longitude           fare  pick_up_distance  day_of_week_num  \
# count       265052.000000  265052.000000     144538.000000    265052.000000
# mean           121.043300     144.682991          1.258156         2.882004
# std              0.188641     200.334292         35.076382         1.799339
# min            119.387860       0.000000          0.000896         0.000000
# 25%            121.016204       0.000000          0.485546         1.000000
# 50%            121.034070     168.125000          0.941601         3.000000
# 75%            121.055217     242.500000          1.652395         4.000000
# max            126.236204   24703.125000      13332.300000         6.000000
#
#          hour_of_day  month_day_num
# count  265052.000000  265052.000000
# mean       14.300601      17.131502
# std         5.960864       7.793082
# min         0.000000       1.000000
# 25%        10.000000      11.000000
# 50%        16.000000      18.000000
# 75%        19.000000      23.000000
# max        23.000000      31.000000
